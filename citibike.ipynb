# %%
# Dependencies
import pandas as pd

# %%
# List of file names to be combined
files = ['data/tripdata1.csv/JC-202212-citibike-tripdata.csv', 'data/tripdata2.csv/JC-202301-citibike-tripdata.csv', 'data/tripdata3.csv/JC-202302-citibike-tripdata.csv', 'data/tripdata4csv/JC-202303-citibike-tripdata.csv', 'data/tripdata5.csv/JC-202304-citibike-tripdata.csv']

# Create an empty list to store each dataframe
df_list = []

# Loop through each file in the list
for file in files:
    # Read the file into a dataframe
    df_files = pd.read_csv(file)

    # Append the dataframe to the list
    df_list.append(df_files)

# Concatenate all dataframes in the list into one dataframe
df_files = pd.concat(df_list)

# Show dataframe
df_files
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      099D81CA71EBADAB   classic_bike  2022-12-23 16:02:26
# 1      D979F3B79FC30F1F  electric_bike  2022-12-27 10:54:29
# 2      3950909BC3B42E43   classic_bike  2022-12-31 10:39:39
# 3      372E50F5FB4FD434   classic_bike  2022-12-05 08:16:10
# 4      AB701FB8091C7431   classic_bike  2022-12-02 13:40:36
# ...                 ...            ...                  ...
# 80683  DB10C78061D8DE72  electric_bike  2023-04-04 19:58:21
# 80684  540F192D0FEF0DCE   classic_bike  2023-04-14 18:46:17
# 80685  74353C7251042C05   classic_bike  2023-04-04 20:16:23
# 80686  F4B95B8815759FEF  electric_bike  2023-04-25 16:34:56
# 80687  46E6A207C37D3567  electric_bike  2023-04-09 09:56:42
#
#                   ended_at                      start_station_name  \
# 0      2022-12-23 16:09:40  Mama Johnson Field - 4 St & Jackson St
# 1      2022-12-27 10:59:23                            Jersey & 3rd
# ...

# %%
# Save the dataframe to a CSV file
df_files.to_csv('data/citibike.csv', index=False)
